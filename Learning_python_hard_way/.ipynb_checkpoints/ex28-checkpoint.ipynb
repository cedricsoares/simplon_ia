# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
True and True #true
# Out:
# True

# %%
False and True #true
# Out:
# False

# %%
1 == 1 and 2 == 1 #false
# Out:
# False

# %%
"test" == "test" #true
# Out:
# True

# %%
1 == 1 or 2 != 1 #true
# Out:
# True

# %%
True and 1 == 1 #true
# Out:
# True

# %%
False and 0 !=0 #false
# Out:
# False

# %%
True or 1 == 1 #true
# Out:
# True

# %%
"test" == "testing" #false
# Out:
# False

# %%
1 != 0 and 2 == 1 #false
# Out:
# False

# %%
"test" != "testing" #true
# Out:
# True

# %%
"test" == 1 #false
# Out:
# False

# %%
not (True and False) #true
# Out:
# True

# %%
not ( 1 == 1 and 0 != 1 ) #false
# Out:
# False

# %%
not ( 10 == 1 or 1000 == 1000 ) #false
# Out:
# False

# %%
not ( 1 != 10 or 3 == 4  ) #false
# Out:
# False

# %%
not ("testing" == "testing" and "zed" == "Cool") #true
# Out:
# True

# %%
1 == 1 and (not ("testting" == 1 or 1 == 0)) #true
# Out:
# True

# %%
"chunky" == "bacon" and ( not ( 3 == 4 or 3 == 3) ) #false
# Out:
# False

# %%
3 == 3 and ( not ("testing" == "testing" or "Python" == "fun" )) #false
# Out:
# False

# %%
True and 2 #if true returns value insted of Boolean
# Out:
# 2
