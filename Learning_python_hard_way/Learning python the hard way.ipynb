# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Hello World!")
print("Hello Again")
print("I like typing this.")
print("This is fun.")
print('Yay! Printing.')
print("I'd much rather you 'nit'.")
print('I "said" do not touch this.')
# Out:
# Hello World!
# Hello Again
# I like typing this.
# This is fun.
# Yay! Printing.
# I'd much rather you 'nit'.
# I "said" do not touch this.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# A comment, this is so you can read your program later.
# Anything after the # is ignored by python.

print("I could have code like this.") # and the comment after is ignored

# You can also use a comment to "disable" or comment your code:
# print ("This will run")

print("This will run.")
# Out:
# I could have code like this.
# This will run.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# print sentence
print("I will now count my chickens:")

# do calculation of Hens and print result
print("Hens", float(25 + 30 / 6))

# do calculation of Rossters and print the result
print("Rossters", float(100 - 25 * 3 % 4))

# print sentence
print("Now I will count the eggs: ")

# do calculation
print(float(3 + 2 + 1 - 5 + 4 % 2 - 1 / 4 + 6))

# print sentence explainning test 5 < 2
print("Is it true that 3 + 2 < 5 - 7 ? ")

# print test result of 5 < 2 test
print(float(3 + 2) < float(5) - float(7))

# print sentence en result of calculation 3 + 2
print("What is 3 + 2?", float(3) + float(2))


# print sentence and calculation 5 - 7
print("What is 5 - 7?", float(5 - 7))

# print sentence
print("Oh, that's why it's False.")

# print sentence
print("How about some more.")

# print sentence and test 5 > - 2
print("Is it greater?", float(5) > float(-2))

# print sentence and test 5 >= 2
print("Is it greater of equal?", float(5) >= float(-2))

# print sentence and test 5 <= -2 
print("Is it less or equal ?", float(5) <= float(-2))
# Out:
# I will now count my chickens:
# Hens 30.0
# Rossters 97.0
# Now I will count the eggs:
# 6.75
# Is it true that 3 + 2 < 5 - 7 ?
# False
# What is 3 + 2? 5.0
# What is 5 - 7? -2.0
# Oh, that's why it's False.
# How about some more.
# Is it greater? True
# Is it greater of equal? True
# Is it less or equal ? False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# assign 100 to car variable
cars = 100

# assign 4.0 to space_in_car variable 
space_in_a_car = 4.0

# assign 30 to drivers variable
drivers = 30

# assign 90 to passenegers variable
passengers = 90

# assign cars - drivers substract to cars_not_driven variable
cars_not_driven = cars - drivers 

# assign drivers varibale value to cars_driven variable
cars_driven = drivers

# assign cars_driven * space_in_car multiplication to carpool_capaicity variable
carpool_capacity = cars_driven * space_in_a_car

# assign passenger / cars_driven division to average_passengers_per_car variable
average_passengers_per_car = passengers / cars_driven

# print a sentence with number of cars value
print("There are", cars, "cars available.")

# print a sentence with number of drivers value
print("The are only", drivers, "drivers available. ")

# print a sentence with number of cars_not_driven value
print("The will be", cars_not_driven, "emty cars today.")

# print a sentence with carpolol_capacity value
print("We can transport", carpool_capacity, "people today.")

# print a sentence with passengers value
print("We have", passengers, "to carpool today.")

# print a sentence with average_passengers_per_car value
print("Wee neeed tu put about", average_passengers_per_car,
     "in each car.")
# Out:
# There are 100 cars available.
# The are only 30 drivers available.
# The will be 70 emty cars today.
# We can transport 120.0 people today.
# We have 90 to carpool today.
# Wee neeed tu put about 3.0 in each car.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = 'Zed A. Shaw'
age = 35 # not a lie
height = 74 # inches
weight = 180 # lbs
eyes = 'Blue'
teeth = 'White'
hair = 'Brown'

heigh_in_cm = height  * 2.4
print(heigh_in_cm)

weight_in_kg = weight / 2.21
print(weight_in_kg)

print(f"Let's talk about {name}.")
print(f"He's {height} inches all.")
print(f"He's {weight} pounds heavy.")
print("Actually tht's not too heavy.")
print(f"He's got {eyes} eyes and {hair} hair.")
print(f"His teeth are usually {teeth} depending on the coffee.")

# this line is tricky, try ti get it exactly right
total = age + height + weight
print(f"If I add {age}, {height}, and {weight} I get {total}.")
# Out:
# 177.6
# 81.44796380090497
# Let's talk about Zed A. Shaw.
# He's 74 inches all.
# He's 180 pounds heavy.
# Actually tht's not too heavy.
# He's got Blue eyes and Brown hair.
# His teeth are usually White depending on the coffee.
# If I add 35, 74, and 180 I get 289.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# assign 10 to types_of_people 
types_of_people = 10

# print a string with types_of_people value
x = f"The are {types_of_people} types of people."

# asign "binary" to binary variable
binary = "binary"

# asign "don't" to do_not variable
do_not = "don't"

# assign string with binay and do_not values
y = f"Those who know {binary} and those whi {do_not}."

print(x)
print(y)

print(f"I said : {x}")
print(f"I also said : '{y}'")

hilarious = False
joke_evaluation = "Isn't tha joke so funny ?! {} "

print(joke_evaluation.format(hilarious))

w = "This is the left side of ..."
e = "a string with right side."

print(w + e)
# Out:
# The are 10 types of people.
# Those who know binary and those whi don't.
# I said : The are 10 types of people.
# I also said : 'Those who know binary and those whi don't.'
# Isn't tha joke so funny ?! False
# This is the left side of ...a string with right side.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Mary had a little lamb.")
print("Its fleeece was white as {}".format('snow'))
print("And everywhere that Mary went.")
print("." * 10) #what'd that do?

end1 = "C"
end2 = "h"
end3 = "e"
end4 = "e"
end5 = "s"
end6 = "e"
end7 = "B"
end8 = "u"
end9 = "r"
end10 = "g"
end11 = "e"
end12 = "r"

# whatch end = ' ' at the end. try removing it to see what happens
print(end1 + end2 + end3 + end4 + end5 + end6, end= ' ')
print(end7 + end8 + end9 + end10 + end11 + end12)
# Out:
# Mary had a little lamb.
# Its fleeece was white as snow
# And everywhere that Mary went.
# ..........
# Cheese Burger

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
formatter = "{} {} {} {}"

print(formatter.format(1,2,3,4))
print(formatter.format("one", "two", "three", "four"))
print(formatter.format(True,  False, False, True))
print(formatter.format(formatter, formatter, formatter, formatter))
print(formatter.format(
    "Try your",
    "Iwn text here",
    "Maybe a poem",
    "Or a song about fear"
))
# Out:
# 1 2 3 4
# one two three four
# True False False True
# {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
# Try your Iwn text here Maybe a poem Or a song about fear

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Here's some new strange stuff, remember type it exactly.

days = "Mon Tue Wed Thu Fri Sat Sun"
months = "Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug"

print("Here are the days: ", days)
print("Here are the months: ", months)

print("""
There's something going on here.
With the three double-quotes.
We'll be able to type as much as we like.
Even 4 lines if we want, or 5, or 6.
""")
# Out:
# Here are the days:  Mon Tue Wed Thu Fri Sat Sun
# Here are the months:  Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
#
# There's something going on here.
# With the three double-quotes.
# We'll be able to type as much as we like.
# Even 4 lines if we want, or 5, or 6.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tabby_cat = "\tI'm tabbed in."
persian_cat = "I'm split\non a line."
backslash_cat = "I'm \\ a \\ cat."

fat_cat = """
I'll do a list:
\t* Cat food
\t* Fishies
\t* Catnip\n\t* Grass
"""

print(tabby_cat)
print(persian_cat)
print(backslash_cat)
print(fat_cat)
# Out:
# 	I'm tabbed in.
# I'm split
# on a line.
# I'm \ a \ cat.
#
# I'll do a list:
# 	* Cat food
# 	* Fishies
# 	* Catnip
# 	* Grass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("How old are you?", end=' ')
age = input()
print("How tall are you?", end=' ')
height = input()
print("How much do you weigh?", end= ' ')
weight = input()

print(f"So, your're {age} old, {height} tall and {weight} heavy.")
# Out:
# How old are you? 37
# How tall are you? 178
# How much do you weigh? 78
# So, your're 37 old, 178 tall and 78 heavy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = input("How old are you? ")
height = input("How tall are you? ")
weight = input("How much do you weight ")

print(f"So, you're {age} old, {height} tall and {weight} heavy." )
# Out:
# How old are you? 37
# How tall are you? 178
# How much do you weight 78
# So, you're 37 old, 178 tall and 78 heavy.
