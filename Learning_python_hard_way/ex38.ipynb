# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ten_things = "Apples Oranges Crows Telephone Ligh Sugar"

print("Wait there are not 10 things in that list. Let's fix taht.")

stuff = ten_things.split(' ')
more_stuff = ["Day", "Night", "Song", "Frisbee", "Corn", "Banana", "Girl", "Boy"]

while len(stuff) != 10:
    next_one = more_stuff.pop()
    print("Adding: ", next_one)
    stuff.append(next_one)
    print(f"There are {len(stuff)} items now.")
    
print("There we go: ", stuff)

print("Let's do some things with  stuff.")

print(stuff[1])
print(stuff[-1]) #whoa! fancy
print(' '.join(stuff)) # what? cool !
print('#'.join(stuff[3:5])) #super stellar!
# Out:
# Wait there are not 10 things in that list. Let's fix taht.
# Adding:  Boy
# There are 7 items now.
# Adding:  Girl
# There are 8 items now.
# Adding:  Banana
# There are 9 items now.
# Adding:  Corn
# There are 10 items now.
# There we go:  ['Apples', 'Oranges', 'Crows', 'Telephone', 'Ligh', 'Sugar', 'Boy', 'Girl', 'Banana', 'Corn']
# Let's do some things with  stuff.
# Oranges
# Corn
# Apples Oranges Crows Telephone Ligh Sugar Boy Girl Banana Corn
# Telephone#Ligh

# %%
# rewrite whit a for loop

ten_things = "Apples Oranges Crows Telephone Ligh Sugar"

print("Wait there are not 10 things in that list. Let's fix taht.")

stuff = ten_things.split(' ')
more_stuff = ["Day", "Night", "Song", "Frisbee", "Corn", "Banana", "Girl", "Boy"]

for article in more_stuff:
    if len(stuff) != 10:
        next_one = more_stuff.pop()
        print("Adding: ", next_one)
        stuff.append(next_one)
        print(f"There are {len(stuff)} items now.")
    
print("There we go: ", stuff)

print("Let's do some things with  stuff.")

print(stuff[1])
print(stuff[-1]) #whoa! fancy
print(' '.join(stuff)) # what? cool !
print('#'.join(stuff[3:5])) #super stellar!
# Out:
# Wait there are not 10 things in that list. Let's fix taht.
# Adding:  Boy
# There are 7 items now.
# Adding:  Girl
# There are 8 items now.
# Adding:  Banana
# There are 9 items now.
# Adding:  Corn
# There are 10 items now.
# There we go:  ['Apples', 'Oranges', 'Crows', 'Telephone', 'Ligh', 'Sugar', 'Boy', 'Girl', 'Banana', 'Corn']
# Let's do some things with  stuff.
# Oranges
# Corn
# Apples Oranges Crows Telephone Ligh Sugar Boy Girl Banana Corn
# Telephone#Ligh
