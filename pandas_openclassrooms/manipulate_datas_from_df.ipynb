# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic') #load the Titanic bDataset included in seaborn library

# %%
titanic.head() #print 5 first entries
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.age.unique() #print uniques values in a column
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.describe() #print count mean std min quartiles max
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.fillna(method='pad').age.head(10) # fill NaN cells with previous value
# Out:
# 1     38.0
# 3     35.0
# 6     54.0
# 10     4.0
# 11    58.0
# 21    34.0
# 23    28.0
# 27    19.0
# 52    49.0
# 54    65.0
# Name: age, dtype: float64

# %%
titanic.fillna(value={'age': 0}).age.head(10) #fill NaN cells of a collums with a specific value
# Out:
# 1     38.0
# 3     35.0
# 6     54.0
# 10     4.0
# 11    58.0
# 21    34.0
# 23    28.0
# 27    19.0
# 52    49.0
# 54    65.0
# Name: age, dtype: float64

# %%
titanic = titanic.dropna() #drop rows of colls with NaN values

# %%
titanic.dropna(axis='columns').head()  #specify the axis

# %%
titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
titanic.rename(columns={'sex' : 'sexe'}) #rename a column
# Out:
#      survived  pclass    sexe   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 21          1       2    male  34.0      0      0   13.0000        S  Second
# 23          1       1    male  28.0      0      0   35.5000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 52          1       1  female  49.0      1      0   76.7292        C   First
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 62          0       1    male  45.0      1      0   83.4750        S   First
# ...

# %%
titanic.drop(1) #drop a specific row
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 21          1       2    male  34.0      0      0   13.0000        S  Second
# 23          1       1    male  28.0      0      0   35.5000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 52          1       1  female  49.0      1      0   76.7292        C   First
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 62          0       1    male  45.0      1      0   83.4750        S   First
# 66          1       2  female  29.0      0      0   10.5000        S  Second
# ...

# %%
titanic.drop(columns=['age']) #drop a column by label
# Out:
#      survived  pclass     sex  sibsp  parch      fare embarked   class    who  \
# 1           1       1  female      1      0   71.2833        C   First  woman
# 3           1       1  female      1      0   53.1000        S   First  woman
# 6           0       1    male      0      0   51.8625        S   First    man
# 10          1       3  female      1      1   16.7000        S   Third  child
# 11          1       1  female      0      0   26.5500        S   First  woman
# 21          1       2    male      0      0   13.0000        S  Second    man
# 23          1       1    male      0      0   35.5000        S   First    man
# 27          0       1    male      3      2  263.0000        S   First    man
# 52          1       1  female      1      0   76.7292        C   First  woman
# 54          0       1    male      0      1   61.9792        C   First    man
# 62          0       1    male      1      0   83.4750        S   First    man
# ...

# %%
titanic.pivot_table('survived', index='sex', columns='class', aggfunc='sum') #print groupby index  dynamic cross table
# Out:
# class   First  Second  Third
# sex
# female     71       8      3
# male       35       4      2

# %%
titanic.pivot_table('survived', index='sex', columns='class') #if aggfunc not specified, prints the mean of each
# Out:
# class      First    Second  Third
# sex
# female  0.959459  0.888889    0.6
# male    0.421687  0.666667    0.4

# %%
titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
age = pd.cut(titanic['age'], [0, 18, 80]) #divide a column in two subsets of values

# %%
titanic.pivot_table('survived', ['sex', 'age'], 'class') #print groupby female and male with subsets 0 to 18 and 18 to 80 with means
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.500000
#        (18, 80]  0.968254  0.875000  0.666667
# male   (0, 18]   0.800000  1.000000  1.000000
#        (18, 80]  0.397436  0.333333  0.250000
